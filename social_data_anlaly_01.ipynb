# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/bigdata_raejung/blob/main/social_data_anlaly_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 1.파일바꾸기 sav->txt

# %%
# import pandas as pd
# import pyreadstat

# # txt 파일 읽기 (구분자가 콤마일 경우)
# df = pd.read_csv("/content/전국사업체조사.txt", sep="\t", encoding='cp949')

# pyreadstat.write_sav(df, "전국사업체조사.sav")

# %%
import pandas as pd
import pyreadstat

# txt 파일 읽기 (구분자가 콤마일 경우)
df = pd.read_csv("/content/전국사업체조사.txt", sep="\t", encoding='utf-8-sig')

pyreadstat.write_sav(df, "전국사업체조사.sav")

# %%
from typing import List

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for i in range(len(nums)):
            firstNum = nums[i]
            for j in range(1, len(nums)):
                secondNum = nums[j]
                if firstNum + secondNum == target:
                    return [i,j]
        return [-1, -1]

# %%
nums = [2,7,11,15]
target = 9

# %%
sol = Solution()
sol.twoSum(nums, target)
# Out:
# [0, 1]

# %% [markdown]
# ## leetcode 문제_02

# %%
# 이 문제는 Add Two Numbers 문제로, 두 연결 리스트에 저장된 숫자를 더하는 문제입니다.
# 숫자가 역순으로 저장되어 있기 때문에 자리 올림(carry) 을 처리하면서 노드를 하나씩 더하면 됩니다.

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def addTwoNumbers(self, l1, l2):
        dummy = ListNode(0)  # 결과 리스트의 시작점
        current = dummy
        carry = 0

        while l1 or l2 or carry:
            v1 = l1.val if l1 else 0
            v2 = l2.val if l2 else 0

            total = v1 + v2 + carry
            carry = total // 10

            current.next = ListNode(total % 10)
            current = current.next

            if l1:
                l1 = l1.next
            if l2:
                l2 = l2.next

        return dummy.next

# %%
# l1 = ListNode(2, ListNode(4, ListNode(3)))   # l1=[2,4,3]
# l2 = ListNode(5, ListNode(6, ListNode(4)))   # l2=[5,6,4]

# %%
l1= ListNode(0)
l2= ListNode(0)

# %%
sol = Solution()
result = sol.addTwoNumbers(l1, l2)

# %%
while result:
    print(result.val, end=" ")
    result = result.next
# Out:
# 0

# %% [markdown]
# #### l1 = [9,9,9,9,9,9,9]  # 9,999,999
# l2 = [9,9,9,9]        #     9,999 인경우

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


def build_list(arr):
    dummy = ListNode(0)
    cur = dummy

    for v in arr:
        cur.next = ListNode(v)
        cur = cur.next

    return dummy.next


class Solution:
    def addTwoNumbers(self, l1, l2):
        dummy = ListNode(0)
        cur = dummy
        carry = 0

        while l1 or l2 or carry:

            v1 = l1.val if l1 else 0
            v2 = l2.val if l2 else 0

            total = v1 + v2 + carry
            carry = total // 10

            cur.next = ListNode(total % 10)
            cur = cur.next

            if l1:
                l1 = l1.next
            if l2:
                l2 = l2.next

        return dummy.next


l1 = build_list([9,9,9,9,9,9,9])
l2 = build_list([9,9,9,9])

sol = Solution()
result = sol.addTwoNumbers(l1, l2)

while result:
    print(result.val, end=" ")
    result = result.next
# Out:
# 8 9 9 9 0 0 0 1

# %%
l1 = [9,9,9,9,9,9,9]  # 9,999,999
l2 = [9,9,9,9]        #     9,999

# %% [markdown]
# ## 1.지민 직무만족도.txt -> 파이썬으로

# %%
import pandas as pd
# 데이터 불러오기
df = pd.read_csv('/content/직무만족도.txt', sep="\t")
print(df.shape)
df.head()
# Out:
# (200, 10)
#    ID  S1  S2  S3  S4  S5  Sat  gender  age  period
# 0   1   1   1   4   5   4    3       1   22       1
# 1   2   4   4   4   5   5    4       1   23       1
# 2   3   7   7   5   4   5    5       1   25       1
# 3   4   4   4   3   4   3    3       1   25       1
# 4   5   4   1   4   4   4    4       1   26       1

# %%
# -----------------------------
# 문제1
# -----------------------------

# (1) 성별 빈도 및 퍼센트
gender_freq = df['gender'].value_counts().sort_index()
gender_pct = df['gender'].value_counts(normalize=True).sort_index() * 100
print("성별 빈도\n", gender_freq)
print("성별 퍼센트\n", gender_pct)
# Out:
# 성별 빈도
#  gender
# 1    128
# 2     72
# Name: count, dtype: int64
# 성별 퍼센트
#  gender
# 1    64.0
# 2    36.0
# Name: proportion, dtype: float64

# %%
# (2) 연령 범주화
def age_group(age):
    if age <= 39:
        return "30대 이하"
    elif age <= 49:
        return "40대"
    else:
        return "50대 이상"

df['age_group']= df['age'].apply(age_group)

df.head()
# Out:
#    ID  S1  S2  S3  S4  S5  Sat  gender  age  period age_group
# 0   1   1   1   4   5   4    3       1   22       1    30대 이하
# 1   2   4   4   4   5   5    4       1   23       1    30대 이하
# 2   3   7   7   5   4   5    5       1   25       1    30대 이하
# 3   4   4   4   3   4   3    3       1   25       1    30대 이하
# 4   5   4   1   4   4   4    4       1   26       1    30대 이하

# %%
age_freq = df['age_group'].value_counts()
age_pct = df['age_group'].value_counts(normalize=True) * 100
print("\n연령대 빈도\n", age_freq)
print("연령대 퍼센트\n", age_pct)
# Out:
# 연령대 빈도
#  age_group
# 30대 이하    139
# 50대 이상     35
# 40대        26
# Name: count, dtype: int64
# 연령대 퍼센트
#  age_group
# 30대 이하    69.5
# 50대 이상    17.5
# 40대       13.0
# Name: proportion, dtype: float64

# %%
# -----------------------------
# 문제2 (성별에 따른 Sat 차이: t-test)
# -----------------------------

# (1) 가설
# H0: μ1 = μ2
# H1: μ1 ≠ μ2

# %%
# (2) 평균
print("성별 평균: \n", df.groupby('gender')['Sat'].mean())
# Out:
# 성별 평균:
#  gender
# 1    4.671875
# 2    4.611111
# Name: Sat, dtype: float64

# %%
from scipy import stats

# (3) t-test
g1 = df[df['gender']==1]['Sat']
g2 = df[df['gender']==2]['Sat']

t_stat, p_val = stats.ttest_ind(g1, g2, equal_var=True)
print("nT-test 결과")
print("t값:", round(t_stat, 3))
print("p값:", round(p_val, 3))
# Out:
# nT-test 결과
# t값: 0.279
# p값: 0.781

# %%
# -----------------------------
# 문제3
# -----------------------------

# S5 역코딩 (최대값 7 기준이라고 가정)
df['S5_rev'] = 8 - df['S5']
df.head()
# Out:
#    ID  S1  S2  S3  S4  S5  Sat  gender  age  period age_group  S5_rev
# 0   1   1   1   4   5   4    3       1   22       1    30대 이하       4
# 1   2   4   4   4   5   5    4       1   23       1    30대 이하       3
# 2   3   7   7   5   4   5    5       1   25       1    30대 이하       3
# 3   4   4   4   3   4   3    3       1   25       1    30대 이하       5
# 4   5   4   1   4   4   4    4       1   26       1    30대 이하       4

# %%
# 직무내적(Y1): S1,S2,S3
df['Y1'] = df[['S1', 'S2', 'S3']].mean(axis=1)

# 직무외적(Y2): S4,S5_rev
df['Y2'] = df[['S4', 'S5_rev']].mean(axis=1)

df.head()
# Out:
#    ID  S1  S2  S3  S4  S5  Sat  gender  age  period age_group  S5_rev  \
# 0   1   1   1   4   5   4    3       1   22       1    30대 이하       4
# 1   2   4   4   4   5   5    4       1   23       1    30대 이하       3
# 2   3   7   7   5   4   5    5       1   25       1    30대 이하       3
# 3   4   4   4   3   4   3    3       1   25       1    30대 이하       5
# 4   5   4   1   4   4   4    4       1   26       1    30대 이하       4
#
#          Y1   Y2
# 0  2.000000  4.5
# 1  4.000000  4.0
# 2  6.333333  3.5
# 3  3.666667  4.5
# 4  3.000000  4.0

# %%
# (1) 평균
print("Y1 평균:", round(df['Y1'].mean(), 1))
print("Y2 평균:", round(df['Y2'].mean(), 1))
# Out:
# Y1 평균: 3.6
# Y2 평균: 4.0

# %%
# (2) 상관계수
corr = df['Y1'].corr(df['Y2'])
print("상관계수: ", corr)
# Out:
# 상관계수:  0.05625376069505754

# %%
# -----------------------------
# 문제4 (연령대별 Sat 차이: ANOVA)
# -----------------------------

# (1) 가설
# H0: μ1 = μ2 = μ3
# H1: 적어도 하나 다름

# %%
# (2) 기술통계
print("연령대별 Sat 기술통계")
print(df.groupby('age_group')['Sat'].describe())
# Out:
# 연령대별 Sat 기술통계
#            count      mean       std  min  25%  50%  75%  max
# age_group
# 30대 이하     139.0  4.489209  1.461421  1.0  4.0  5.0  5.5  7.0
# 40대         26.0  4.692308  1.289007  2.0  4.0  5.0  6.0  7.0
# 50대 이상      35.0  5.257143  1.540490  1.0  5.0  5.0  6.0  7.0

# %%
import statsmodels.api as sm
from statsmodels.formula.api import  ols   # ols : OLS는 회귀분석에서 가장 기본이 되는 **최소제곱법(Ordinary Least Squares)
# (3) ANOVA
model = ols('Sat ~ C(age_group)', data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Sat   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     3.908
# Date:                Sat, 28 Mar 2026   Prob (F-statistic):             0.0217
# Time:                        09:45:46   Log-Likelihood:                -357.25
# No. Observations:                 200   AIC:                             720.5
# Df Residuals:                     197   BIC:                             730.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
anova_table = sm.stats.anova_lm(model, typ=2)
print("ANOVA 결과 : ", anova_table)
# Out:
# ANOVA 결과 :                    sum_sq     df         F   PR(>F)
# C(age_group)   16.542011    2.0  3.907799  0.02166
# Residual      416.957989  197.0       NaN      NaN

# %%
from statsmodels.stats.multicomp import MultiComparison

# (5) Duncan 대신 Tukey (Python 기본)
mc = MultiComparison(df['Sat'], df['age_group'])
tukey = mc.tukeyhsd()
print("사후분석 (Tukey) : ", tukey)
# Out:
# 사후분석 (Tukey) :  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
# 30대 이하    40대   0.2031 0.7907  -0.531 0.9372  False
# 30대 이하 50대 이상   0.7679 0.0158  0.1182 1.4177   True
#    40대 50대 이상   0.5648 0.2933 -0.3247 1.4544  False
# ---------------------------------------------------

# %%
# -----------------------------
# 문제5 (교차분석 + 카이제곱)
# -----------------------------

# 교차표 (행 퍼센트)
ct = pd.crosstab(df['age_group'], df['period'], normalize='index') * 100
print("교차표 (행 퍼센트) : ", ct)
# Out:
# 교차표 (행 퍼센트) :  period             1          2          3          4          5
# age_group
# 30대 이하     29.496403  30.215827  28.776978  11.510791   0.000000
# 40대         0.000000  30.769231  11.538462  30.769231  26.923077
# 50대 이상      5.714286   8.571429   2.857143   2.857143  80.000000

# %%
# 카이제곱 검정
ct_raw = pd.crosstab(df['age_group'], df['period'])
chi2, p_val, dof, exp = stats.chi2_contingency(ct_raw)
chi2, p_val, dof, exp
# Out:
# (np.float64(142.37792483890007),
#  np.float64(7.595211062184674e-27),
#  8,
#  array([[29.885, 36.835, 30.58 , 17.375, 24.325],
#         [ 5.59 ,  6.89 ,  5.72 ,  3.25 ,  4.55 ],
#         [ 7.525,  9.275,  7.7  ,  4.375,  6.125]]))

# %%
print("카이제곱 검정")
print("chi2:", chi2)
print("p_val값:", p_val)
# Out:
# 카이제곱 검정
# chi2: 142.37792483890007
# p_val값: 7.595211062184674e-27

# %%
# -----------------------------
# 문제6 (중회귀분석)
# -----------------------------
X = df[['Y1', 'Y2', 'age']]
X = sm.add_constant(X)
y = df['Sat']

model = sm.OLS(y, X).fit()
print("회귀분석 결과")
print(model.summary())
# Out:
# 회귀분석 결과
#                             OLS Regression Results
# ...
# Dep. Variable:                    Sat   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     14.76
# Date:                Sat, 28 Mar 2026   Prob (F-statistic):           1.06e-08
# Time:                        10:04:49   Log-Likelihood:                -340.78
# No. Observations:                 200   AIC:                             689.6
# Df Residuals:                     196   BIC:                             702.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.1819      0.648      4.910      0.000       1.904       4.460
# ...

# %%
# 회귀식 출력
coef = model.params
print("회귀식:")
print(f"Sat = {coef['const']:.3f} + {coef['Y1']:.3f}*Y1 + {coef['Y2']:.3f}*Y2 + {coef['age']:.3f}*age")
# Out:
# 회귀식:
# Sat = 3.182 + 0.376*Y1 + -0.175*Y2 + 0.021*age

# %% [markdown]
# ## 1_1 지민 직무만족도를 pytorch로 구현

# %%
import pandas as pd

# %%
# 데이터 불러오기
df = pd.read_csv('/content/직무만족도.txt', sep='\t')
df.head()
# Out:
#    ID  S1  S2  S3  S4  S5  Sat  gender  age  period
# 0   1   1   1   4   5   4    3       1   22       1
# 1   2   4   4   4   5   5    4       1   23       1
# 2   3   7   7   5   4   5    5       1   25       1
# 3   4   4   4   3   4   3    3       1   25       1
# 4   5   4   1   4   4   4    4       1   26       1

# %%
# =========================
# 1. GPU 설정
# =========================
import torch
import pandas as pd

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("사용 장치:", device)
# Out:
# 사용 장치: cuda

# %%
# =========================
# 2. 데이터 불러오기
# =========================
# Colab에 파일 업로드 후 실행
from google.colab import files
# uploaded = files.upload()

df = pd.read_csv("/content/직무만족도.txt", sep="\t")
df.head()
# Out:
#    ID  S1  S2  S3  S4  S5  Sat  gender  age  period
# 0   1   1   1   4   5   4    3       1   22       1
# 1   2   4   4   4   5   5    4       1   23       1
# 2   3   7   7   5   4   5    5       1   25       1
# 3   4   4   4   3   4   3    3       1   25       1
# 4   5   4   1   4   4   4    4       1   26       1

# %%
df.describe()
# Out:
#                ID          S1          S2          S3          S4          S5  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000    3.515000    3.595000    3.840000    4.795000    4.840000
# std     57.879185    2.182566    2.145692    1.814071    1.595526    1.825118
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%     50.750000    2.000000    2.000000    3.000000    4.000000    4.000000
# 50%    100.500000    3.000000    3.000000    4.000000    5.000000    5.000000
# 75%    150.250000    5.000000    5.000000    5.000000    6.000000    6.000000
# max    200.000000    9.000000    9.000000    9.000000    9.000000    9.000000
#
#               Sat      gender         age      period
# count  200.000000  200.000000  200.000000  200.000000
# mean     4.650000    1.360000   37.370000    2.780000
# std      1.475938    0.481205   10.355641    1.382446
# ...

# %%
# tensor 변환 + GPU 이동
data = torch.tensor(df.values, dtype=torch.float32).to(device)

cols = {name: i for i, name in enumerate(df.columns)}

# %%
# =========================
# 문제1
# =========================
gender = data[:, cols['gender']]
total = len(gender)

unique, counts = torch.unique(gender, return_counts=True)
print("\n[문제1-성별]")
# Out:
# [문제1-성별]

# %%
for u, c in zip(unique, counts):
    print(f"{int(u.item())}: {int(c.item())} ({c.item()/total*100:.2f}%)")
# Out:
# 1: 128 (64.00%)
# 2: 72 (36.00%)

# %%
# (2) 연령 범주화
age = data[:, cols['age']]

age_group = []
for a in age:
    if a <= 39:
        age_group.append(0)  # 30대 이하
    elif a <= 49:
        age_group.append(1)  # 40대
    else:
        age_group.append(2)  # 50대 이상

age_group = torch.tensor(age_group)

print("\n연령대 빈도")
for g in [0, 1, 2]:
    count = (age_group==g).sum()
    print(f"{g}: {int(count)} ({count/total*100:.2f}%)")
# Out:
# 연령대 빈도
# 0: 139 (69.50%)
# 1: 26 (13.00%)
# 2: 35 (17.50%)

# %%
# -----------------------------
# 문제2 (t-test 직접 구현)
# -----------------------------
Sat = data[:, cols['Sat']]

g1 = Sat[gender==1]
g2 = Sat[gender==2]

mean1, mean2 = g1.mean(), g2.mean()
var1, var2 = g1.var(unbiased=True), g2.var(unbiased=True)

n1, n2 = len(g1), len(g2)

print(mean1, mean2)
print('\n', var1, var2)
print('\n', n1, n2)
# Out:
# tensor(4.6719, device='cuda:0') tensor(4.6111, device='cuda:0')
#
#  tensor(2.1435, device='cuda:0') tensor(2.2692, device='cuda:0')
#
#  128 72

# %%
# pooled variance
sp = ((n1-1)*var1 + (n2-1)*var2) / (n1+n2-2)

# t-stat
t_stat = (mean1 - mean2) / torch.sqrt(sp*(1/n1 + 1/n2))
print("\n문제2 t값:", t_stat.item())
# Out:
# 문제2 t값: 0.2788205146789551

# %%
# -----------------------------
# 문제3
# -----------------------------
S1 = data[:, cols['S1']]
S2 = data[:, cols['S2']]
S3 = data[:, cols['S3']]
S4 = data[:, cols['S4']]
S5 = data[:, cols['S5']]

# 역코딩 (7점 기준)
S5_rev = 8 - S5

Y1 = torch.stack([S1, S2, S3]).mean(dim=0)
Y2 = torch.stack([S4, S5_rev]).mean(dim=0)

print("Y1 평균:", Y1.mean().item())
print("Y2 평균:", Y2.mean().item())
# Out:
# Y1 평균: 3.6499998569488525
# Y2 평균: 3.9774999618530273

# %%
# 상관계수 (피어슨)
def pearson(x, y):
    xm = x - x.mean()
    ym = y - y.mean()
    return (xm*ym).sum() / torch.sqrt((xm**2).sum()*(ym**2).sum())

# %%
corr = pearson(Y1, Y2)
print("상관계수:", corr.item())
# Out:
# 상관계수: 0.05625377967953682

# %%
# -----------------------------
# 문제4 (ANOVA 직접 구현)
# -----------------------------
groups = [Sat[age_group==i] for i in [0,1,2]]

overall_mean = Sat.mean()

# Between
SSB = sum([len(g)*(g.mean()-overall_mean)**2 for g in groups])

# Within
SSW = sum([((g - g.mean())**2).sum() for g in groups])

dfb = 3-1
dfw = len(Sat)-3

MSB = SSB / dfb
MSW = SSW / dfw

F = MSB / MSW
print("\nANOVA F값:", F.item())
# Out:
# ANOVA F값: 3.9077999591827393

# %%
# -----------------------------
# 문제5 (카이제곱)
# -----------------------------
# GPU → CPU 이동 (핵심!!)
period = data[:, cols['period']]

period_cpu = period.cpu()
age_group_cpu = age_group.cpu()

# 교차표 만들기
ct = {}
for a in [0,1,2]:
    for p in torch.unique(period_cpu):
        ct[(a, int(p.item()))] = int(((age_group_cpu == a) & (period_cpu == p)).sum())

print("교차표")
print(ct)
# Out:
# 교차표
# {(0, 1): 41, (0, 2): 42, (0, 3): 40, (0, 4): 16, (0, 5): 0, (1, 1): 0, (1, 2): 8, (1, 3): 3, (1, 4): 8, (1, 5): 7, (2, 1): 2, (2, 2): 3, (2, 3): 1, (2, 4): 1, (2, 5): 28}

# %%
# (간단 chi-square 계산)
# 기대값 계산용 행/열 합

# GPU → CPU 이동
age_group_cpu = age_group.cpu()
period_cpu = period.cpu()

row_sum = [(age_group_cpu==i).sum().item() for i in [0,1,2]]
col_values = torch.unique(period_cpu)
col_sum = [(period_cpu==c).sum().item() for c in col_values]

N = len(period_cpu)

chi2 = 0
for i,a in enumerate([0,1,2]):
    for j,c in enumerate(col_values):
        O = ((age_group_cpu==a) & (period_cpu==c)).sum().item()
        E = row_sum[i]*col_sum[j]/N
        chi2 += (O-E)**2/E

print("카이제곱 값:", chi2)
# Out:
# 카이제곱 값: 142.37792483890007

# %%
# -----------------------------
# 문제6 (회귀분석: PyTorch)
# -----------------------------

X = torch.stack([Y1, Y2, age], dim=1)
X = torch.cat([torch.ones(len(X), 1).to(device), X], dim=1)
y = Sat.view(-1, 1)

beta = torch.inverse(X.T @ X) @ X.T @ y

print("[문제6]")
print("회귀계수:", beta)
# Out:
# [문제6]
# 회귀계수: tensor([[ 3.1819],
#         [ 0.3764],
#         [-0.1749],
#         [ 0.0211]], device='cuda:0')

# %%
# R^2
y_hat = X @ beta
SS_tot = ((y - y.mean())**2).sum()
SS_res = ((y - y_hat)**2).sum()
R2 = 1 - SS_res/SS_tot

print("R^2:", R2.item())
# Out:
# R^2: 0.18424230813980103

# %%
print("\n회귀식:")
print(f"Sat = {beta[0].item():.3f} + {beta[1].item():.3f}*Y1 + {beta[2].item():.3f}*Y2 + {beta[3].item():.3f}*age")
# Out:
# 회귀식:
# Sat = 3.182 + 0.376*Y1 + -0.175*Y2 + 0.021*age
